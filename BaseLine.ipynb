# %%
################################################################################
# Title= CutMix: Regularization Strategy to Train Strong Classifiers with Localizable Features 
# Author= Yun, Sangdoo and Han, Dongyoon and Oh, Seong Joon and Chun, Sanghyuk and Choe, Junsuk and Yoo, Youngjoon,
# Booktitle = International Conference on Computer Vision (ICCV)
# Year=2019
# Availability: https://github.com/clovaai/CutMix-PyTorch
################################################################################



import os
import shutil
import time

import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
import torch.utils.data.distributed
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models
import numpy as np
import math
import torch.nn.functional as F

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    top1 = AverageMeter()
    top5 = AverageMeter()

    # switch to train mode
    model.train()

    end = time.time()
    current_LR = get_learning_rate(optimizer)[0]
    for i, (input, target) in enumerate(train_loader):
        data_time.update(time.time() - end)        
        input = input.cuda()
        target = target.cuda()
        input_var = torch.autograd.Variable(input, requires_grad=True)
        target_var = torch.autograd.Variable(target)
        output = model(input_var)
        
        loss = criterion(output, target_var)

        # measure accuracy and record loss
        err1, err5 = accuracy(output.data, target, topk=(1, 5))

        losses.update(loss.item(), input.size(0))
        top1.update(err1.item(), input.size(0))
        top5.update(err5.item(), input.size(0))

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if i % print_freq == 0 and verbose == True:
            print('Epoch: [{0}/{1}][{2}/{3}]\t'
                  'LR: {LR:.6f}\t'
                  'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Top 1-err {top1.val:.4f} ({top1.avg:.4f})\t'.format(
                epoch, epochs, i, len(train_loader), LR=current_LR, batch_time=batch_time,
                loss=losses, top1=top1))
    print('* Epoch: [{0}/{1}]\t Top 1-err {top1.avg:.3f}  Top 5-err {top5.avg:.3f}\t Train Loss {loss.avg:.3f}'.format(
        epoch, epochs, top1=top1, top5=top5, loss=losses))

    return losses.avg


def custom_criterion(criterion, pred, labels, split_ratio):
    ls = int(split_ratio*batch_size)

    pred_labeled = pred[:ls]
    pred_unlabeled = pred[ls:]
  
    labels_l = labels[:ls].cuda()

    labels_ul = torch.ones((int(batch_size-ls)),dtype=torch.long).cuda()

    # return (1/ls) * criterion(pred_labeled, labels_l) + (1/(batch_size-ls)) * criterion(pred_unlabeled, labels_ul)
    return criterion(pred_labeled, labels_l) + criterion(pred_unlabeled, labels_ul)
    # return criterion(pred_labeled, labels_l) 

def validate(val_loader, model, criterion, epoch):
    batch_time = AverageMeter()
    losses = AverageMeter()
    top1 = AverageMeter()
    top5 = AverageMeter()

    # switch to evaluate mode
    model.eval()

    end = time.time()
    for i, (input, target) in enumerate(val_loader):
        target = target.cuda()

        input_var = torch.autograd.Variable(input)
        target_var = torch.autograd.Variable(target)
        output = model(input_var)
        loss = criterion(output, target_var)

        # measure accuracy and record loss
        err1, err5 = accuracy(output.data, target, topk=(1, 5))

        losses.update(loss.item(), input.size(0))

        top1.update(err1.item(), input.size(0))
        top5.update(err5.item(), input.size(0))

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if i % print_freq == 0 and verbose == True:
            print('Test (on val set): [{0}/{1}][{2}/{3}]\t'
                  'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Top 1-err {top1.val:.4f} ({top1.avg:.4f})\t'.format(
                   epoch, epochs, i, len(val_loader), batch_time=batch_time, loss=losses,
                   top1=top1))

    print('* Epoch: [{0}/{1}]\t Top 1-err {top1.avg:.3f}  Top 5-err {top5.avg:.3f}\t Test Loss {loss.avg:.3f}'.format(
        epoch, epochs, top1=top1, top5=top5, loss=losses))
    return top1.avg, top5.avg, losses.avg


class AverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def adjust_learning_rate(optimizer, epoch):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    global lr
    
    lr = lr * (0.2 ** (epoch // (epochs * 0.5))) * (0.1 ** (epoch // (epochs * 0.75)))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr


def get_learning_rate(optimizer):
    lr = []
    for param_group in optimizer.param_groups:
        lr += [param_group['lr']]
    return lr


def accuracy(output, target, topk=(1,)):
    maxk = max(topk)
    batch_size = target.size(0)
    _, Y_pred = output.topk(maxk, 1, True, True)
    Y_pred = Y_pred.t()
    correct = Y_pred.eq(target.view(1, -1).expand_as(Y_pred))
    result = []
    for k in topk:
        correct_k = correct[:k].view(-1).float().sum(0, keepdim=True)
        wrong_k = batch_size - correct_k
        result.append(wrong_k.mul_(100.0 / batch_size))

    return result

# %%
class CNN(nn.Module):
    def __init__(self,num_classes=10):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3,64,3,2,1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64,128,3,2,1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128))
        self.out = nn.Linear(128,num_classes)
        
    def forward(self, x, noise=True):
        x = self.conv(x)
        x = F.adaptive_avg_pool2d(x,1).view(-1,128)
        return self.out(x)

# %%
batch_size=100
numberofclass = 10
depth=200
alpha=240
lr=0.1
epochs=300
beta=1.0
print_freq=100
verbose=True
workers=4
momentum=0.9
weight_decay=1e-4
best_err1 = 100
best_err5 = 100
use_cuda = torch.cuda.is_available()
normalize = transforms.Normalize(mean=[x / 255.0 for x in [125.3, 123.0, 113.9]],
                                          std=[x / 255.0 for x in [63.0, 62.1, 66.7]])


transform_train = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])
transform_test = transforms.Compose([
            transforms.ToTensor(),
            normalize
        ])


train_loader = torch.utils.data.DataLoader(
                datasets.CIFAR10('../data', train=True, download=True, transform=transform_train),
                batch_size=batch_size, shuffle=True, num_workers=workers, pin_memory=True)
val_loader = torch.utils.data.DataLoader(
                datasets.CIFAR10('../data', train=False, transform=transform_test),
                batch_size=batch_size, shuffle=True, num_workers=workers, pin_memory=True)

model = CNN()
model = torch.nn.DataParallel(model).cuda()
criterion = nn.CrossEntropyLoss().cuda()
optimizer = torch.optim.SGD(model.parameters(), lr, momentum=momentum, weight_decay=weight_decay, nesterov=True)
cudnn.benchmark = True

for epoch in range(0, 300):

    adjust_learning_rate(optimizer, epoch)

    # train for one epoch
    train_loss = train(train_loader, model, criterion, optimizer, epoch)

    # evaluate on validation set
    err1, err5, val_loss = validate(val_loader, model, criterion, epoch)

    # remember best prec@1 and save checkpoint
    is_best = err1 <= best_err1
    best_err1 = min(err1, best_err1)
    if is_best:
        best_err5 = err5

    print('Current best accuracy (top-1 and 5 error):', best_err1, best_err5)
print('Best accuracy (top-1 and 5 error):', best_err1, best_err5)
# Out:
# 0it [00:00, ?it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
#  98%|█████████▊| 167583744/170498071 [00:11<00:00, 17795726.57it/s]
# Extracting ../data/cifar-10-python.tar.gz to ../data
# Epoch: [0/300][0/500]	LR: 0.100000	Time 0.336 (0.336)	Loss 2.3066 (2.3066)	Top 1-err 92.0000 (92.0000)
# Epoch: [0/300][100/500]	LR: 0.100000	Time 0.004 (0.013)	Loss 1.7865 (1.8709)	Top 1-err 68.0000 (69.9703)
# Epoch: [0/300][200/500]	LR: 0.100000	Time 0.005 (0.012)	Loss 1.4982 (1.7738)	Top 1-err 53.0000 (65.8259)
# Epoch: [0/300][300/500]	LR: 0.100000	Time 0.006 (0.011)	Loss 1.7722 (1.6999)	Top 1-err 67.0000 (62.8804)
# Epoch: [0/300][400/500]	LR: 0.100000	Time 0.012 (0.011)	Loss 1.4287 (1.6546)	Top 1-err 54.0000 (60.8853)
# * Epoch: [0/300]	 Top 1-err 59.492  Top 5-err 10.638	 Train Loss 1.618
# Test (on val set): [0/300][0/100]	Time 0.164 (0.164)	Loss 1.5180 (1.5180)	Top 1-err 46.0000 (46.0000)
# * Epoch: [0/300]	 Top 1-err 53.430  Top 5-err 7.250	 Test Loss 1.496
# Current best accuracy (top-1 and 5 error): 53.43 7.25
# Epoch: [1/300][0/500]	LR: 0.100000	Time 0.164 (0.164)	Loss 1.4222 (1.4222)	Top 1-err 54.0000 (54.0000)
# Epoch: [1/300][100/500]	LR: 0.100000	Time 0.032 (0.012)	Loss 1.2323 (1.4213)	Top 1-err 51.0000 (52.1485)
# Epoch: [1/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.5762 (1.4036)	Top 1-err 53.0000 (51.3980)
# Epoch: [1/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.3667 (1.3908)	Top 1-err 42.0000 (50.3522)
# 170500096it [00:29, 17795726.57it/s]
# Epoch: [1/300][400/500]	LR: 0.100000	Time 0.014 (0.010)	Loss 1.2801 (1.3764)	Top 1-err 47.0000 (49.5661)
# * Epoch: [1/300]	 Top 1-err 49.190  Top 5-err 6.698	 Train Loss 1.366
# Test (on val set): [1/300][0/100]	Time 0.152 (0.152)	Loss 1.1579 (1.1579)	Top 1-err 40.0000 (40.0000)
# * Epoch: [1/300]	 Top 1-err 47.020  Top 5-err 5.940	 Test Loss 1.327
# Current best accuracy (top-1 and 5 error): 47.02 5.94
# Epoch: [2/300][0/500]	LR: 0.100000	Time 0.180 (0.180)	Loss 1.3089 (1.3089)	Top 1-err 51.0000 (51.0000)
# Epoch: [2/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.1579 (1.3115)	Top 1-err 43.0000 (46.7327)
# Epoch: [2/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.1813 (1.3023)	Top 1-err 34.0000 (46.5373)
# Epoch: [2/300][300/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 1.3727 (1.2974)	Top 1-err 46.0000 (46.2326)
# Epoch: [2/300][400/500]	LR: 0.100000	Time 0.007 (0.010)	Loss 1.0885 (1.2909)	Top 1-err 41.0000 (45.9027)
# * Epoch: [2/300]	 Top 1-err 45.630  Top 5-err 5.616	 Train Loss 1.282
# Test (on val set): [2/300][0/100]	Time 0.147 (0.147)	Loss 1.0434 (1.0434)	Top 1-err 34.0000 (34.0000)
# * Epoch: [2/300]	 Top 1-err 45.660  Top 5-err 4.930	 Test Loss 1.267
# Current best accuracy (top-1 and 5 error): 45.66 4.93
# Epoch: [3/300][0/500]	LR: 0.100000	Time 0.174 (0.174)	Loss 1.1336 (1.1336)	Top 1-err 43.0000 (43.0000)
# Epoch: [3/300][100/500]	LR: 0.100000	Time 0.003 (0.012)	Loss 1.2213 (1.2411)	Top 1-err 40.0000 (43.9505)
# Epoch: [3/300][200/500]	LR: 0.100000	Time 0.022 (0.011)	Loss 1.3584 (1.2276)	Top 1-err 47.0000 (43.4577)
# Epoch: [3/300][300/500]	LR: 0.100000	Time 0.005 (0.011)	Loss 1.4594 (1.2269)	Top 1-err 48.0000 (43.5083)
# Epoch: [3/300][400/500]	LR: 0.100000	Time 0.011 (0.011)	Loss 1.0807 (1.2228)	Top 1-err 36.0000 (43.4713)
# * Epoch: [3/300]	 Top 1-err 43.292  Top 5-err 4.924	 Train Loss 1.219
# Test (on val set): [3/300][0/100]	Time 0.136 (0.136)	Loss 1.2336 (1.2336)	Top 1-err 40.0000 (40.0000)
# * Epoch: [3/300]	 Top 1-err 43.970  Top 5-err 4.350	 Test Loss 1.218
# Current best accuracy (top-1 and 5 error): 43.97 4.35
# Epoch: [4/300][0/500]	LR: 0.100000	Time 0.169 (0.169)	Loss 1.0422 (1.0422)	Top 1-err 38.0000 (38.0000)
# Epoch: [4/300][100/500]	LR: 0.100000	Time 0.015 (0.011)	Loss 1.1955 (1.1792)	Top 1-err 44.0000 (41.5248)
# Epoch: [4/300][200/500]	LR: 0.100000	Time 0.026 (0.011)	Loss 1.3591 (1.1901)	Top 1-err 52.0000 (42.0896)
# Epoch: [4/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.2522 (1.1849)	Top 1-err 41.0000 (41.9900)
# Epoch: [4/300][400/500]	LR: 0.100000	Time 0.003 (0.010)	Loss 1.2446 (1.1834)	Top 1-err 48.0000 (41.9252)
# * Epoch: [4/300]	 Top 1-err 41.756  Top 5-err 4.688	 Train Loss 1.178
# Test (on val set): [4/300][0/100]	Time 0.157 (0.157)	Loss 1.1078 (1.1078)	Top 1-err 42.0000 (42.0000)
# * Epoch: [4/300]	 Top 1-err 42.710  Top 5-err 4.870	 Test Loss 1.212
# Current best accuracy (top-1 and 5 error): 42.71 4.87
# Epoch: [5/300][0/500]	LR: 0.100000	Time 0.190 (0.190)	Loss 1.0886 (1.0886)	Top 1-err 31.0000 (31.0000)
# Epoch: [5/300][100/500]	LR: 0.100000	Time 0.003 (0.012)	Loss 1.3439 (1.1803)	Top 1-err 41.0000 (42.0495)
# Epoch: [5/300][200/500]	LR: 0.100000	Time 0.005 (0.011)	Loss 1.0369 (1.1627)	Top 1-err 40.0000 (41.1891)
# Epoch: [5/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.2056 (1.1575)	Top 1-err 43.0000 (41.0731)
# Epoch: [5/300][400/500]	LR: 0.100000	Time 0.023 (0.010)	Loss 1.0214 (1.1521)	Top 1-err 37.0000 (40.8678)
# * Epoch: [5/300]	 Top 1-err 40.790  Top 5-err 4.424	 Train Loss 1.150
# Test (on val set): [5/300][0/100]	Time 0.132 (0.132)	Loss 1.3870 (1.3870)	Top 1-err 46.0000 (46.0000)
# * Epoch: [5/300]	 Top 1-err 41.310  Top 5-err 4.220	 Test Loss 1.183
# Current best accuracy (top-1 and 5 error): 41.31 4.22
# Epoch: [6/300][0/500]	LR: 0.100000	Time 0.175 (0.175)	Loss 1.1029 (1.1029)	Top 1-err 45.0000 (45.0000)
# Epoch: [6/300][100/500]	LR: 0.100000	Time 0.014 (0.012)	Loss 1.1483 (1.1291)	Top 1-err 41.0000 (40.2574)
# Epoch: [6/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9800 (1.1376)	Top 1-err 42.0000 (40.7562)
# Epoch: [6/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.2072 (1.1390)	Top 1-err 39.0000 (40.8937)
# Epoch: [6/300][400/500]	LR: 0.100000	Time 0.008 (0.010)	Loss 1.1677 (1.1306)	Top 1-err 46.0000 (40.6534)
# * Epoch: [6/300]	 Top 1-err 40.402  Top 5-err 4.234	 Train Loss 1.129
# Test (on val set): [6/300][0/100]	Time 0.159 (0.159)	Loss 1.2953 (1.2953)	Top 1-err 43.0000 (43.0000)
# * Epoch: [6/300]	 Top 1-err 41.030  Top 5-err 3.950	 Test Loss 1.192
# Current best accuracy (top-1 and 5 error): 41.03 3.95
# Epoch: [7/300][0/500]	LR: 0.100000	Time 0.188 (0.188)	Loss 1.1367 (1.1367)	Top 1-err 41.0000 (41.0000)
# Epoch: [7/300][100/500]	LR: 0.100000	Time 0.010 (0.012)	Loss 0.9680 (1.1124)	Top 1-err 27.0000 (39.5248)
# Epoch: [7/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.0991 (1.1094)	Top 1-err 41.0000 (39.2488)
# Epoch: [7/300][300/500]	LR: 0.100000	Time 0.020 (0.010)	Loss 1.3880 (1.1103)	Top 1-err 45.0000 (39.2990)
# Epoch: [7/300][400/500]	LR: 0.100000	Time 0.003 (0.010)	Loss 0.9496 (1.1083)	Top 1-err 36.0000 (39.3092)
# * Epoch: [7/300]	 Top 1-err 39.328  Top 5-err 4.072	 Train Loss 1.109
# Test (on val set): [7/300][0/100]	Time 0.127 (0.127)	Loss 1.3442 (1.3442)	Top 1-err 46.0000 (46.0000)
# * Epoch: [7/300]	 Top 1-err 42.230  Top 5-err 4.620	 Test Loss 1.222
# Current best accuracy (top-1 and 5 error): 41.03 3.95
# Epoch: [8/300][0/500]	LR: 0.100000	Time 0.181 (0.181)	Loss 1.0664 (1.0664)	Top 1-err 42.0000 (42.0000)
# Epoch: [8/300][100/500]	LR: 0.100000	Time 0.003 (0.012)	Loss 1.1615 (1.0971)	Top 1-err 41.0000 (38.9703)
# Epoch: [8/300][200/500]	LR: 0.100000	Time 0.031 (0.011)	Loss 0.9690 (1.0919)	Top 1-err 33.0000 (38.6816)
# Epoch: [8/300][300/500]	LR: 0.100000	Time 0.010 (0.011)	Loss 1.2013 (1.0921)	Top 1-err 44.0000 (38.6512)
# Epoch: [8/300][400/500]	LR: 0.100000	Time 0.005 (0.011)	Loss 1.1027 (1.0925)	Top 1-err 39.0000 (38.5337)
# * Epoch: [8/300]	 Top 1-err 38.258  Top 5-err 3.894	 Train Loss 1.088
# Test (on val set): [8/300][0/100]	Time 0.161 (0.161)	Loss 1.1825 (1.1825)	Top 1-err 34.0000 (34.0000)
# * Epoch: [8/300]	 Top 1-err 39.900  Top 5-err 3.570	 Test Loss 1.123
# Current best accuracy (top-1 and 5 error): 39.9 3.57
# Epoch: [9/300][0/500]	LR: 0.100000	Time 0.166 (0.166)	Loss 0.9881 (0.9881)	Top 1-err 29.0000 (29.0000)
# Epoch: [9/300][100/500]	LR: 0.100000	Time 0.004 (0.012)	Loss 1.0302 (1.0795)	Top 1-err 39.0000 (37.8812)
# Epoch: [9/300][200/500]	LR: 0.100000	Time 0.019 (0.011)	Loss 1.0974 (1.0671)	Top 1-err 41.0000 (37.6418)
# Epoch: [9/300][300/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 1.1953 (1.0698)	Top 1-err 41.0000 (37.7010)
# Epoch: [9/300][400/500]	LR: 0.100000	Time 0.015 (0.011)	Loss 1.1076 (1.0697)	Top 1-err 42.0000 (37.8254)
# * Epoch: [9/300]	 Top 1-err 37.764  Top 5-err 3.760	 Train Loss 1.069
# Test (on val set): [9/300][0/100]	Time 0.138 (0.138)	Loss 1.2070 (1.2070)	Top 1-err 38.0000 (38.0000)
# * Epoch: [9/300]	 Top 1-err 39.530  Top 5-err 3.880	 Test Loss 1.151
# Current best accuracy (top-1 and 5 error): 39.53 3.88
# Epoch: [10/300][0/500]	LR: 0.100000	Time 0.161 (0.161)	Loss 1.0357 (1.0357)	Top 1-err 30.0000 (30.0000)
# Epoch: [10/300][100/500]	LR: 0.100000	Time 0.006 (0.011)	Loss 0.7869 (1.0710)	Top 1-err 28.0000 (37.5644)
# Epoch: [10/300][200/500]	LR: 0.100000	Time 0.011 (0.011)	Loss 1.2364 (1.0627)	Top 1-err 39.0000 (37.3781)
# Epoch: [10/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.1238 (1.0675)	Top 1-err 38.0000 (37.6844)
# Epoch: [10/300][400/500]	LR: 0.100000	Time 0.019 (0.010)	Loss 0.9615 (1.0653)	Top 1-err 34.0000 (37.5337)
# * Epoch: [10/300]	 Top 1-err 37.554  Top 5-err 3.670	 Train Loss 1.063
# Test (on val set): [10/300][0/100]	Time 0.162 (0.162)	Loss 1.1671 (1.1671)	Top 1-err 43.0000 (43.0000)
# * Epoch: [10/300]	 Top 1-err 38.510  Top 5-err 3.780	 Test Loss 1.120
# Current best accuracy (top-1 and 5 error): 38.51 3.78
# Epoch: [11/300][0/500]	LR: 0.100000	Time 0.183 (0.183)	Loss 1.0347 (1.0347)	Top 1-err 35.0000 (35.0000)
# Epoch: [11/300][100/500]	LR: 0.100000	Time 0.007 (0.011)	Loss 0.9585 (1.0191)	Top 1-err 34.0000 (36.0000)
# Epoch: [11/300][200/500]	LR: 0.100000	Time 0.021 (0.011)	Loss 1.0318 (1.0371)	Top 1-err 36.0000 (36.6567)
# Epoch: [11/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.8915 (1.0469)	Top 1-err 26.0000 (36.9003)
# Epoch: [11/300][400/500]	LR: 0.100000	Time 0.018 (0.010)	Loss 1.0165 (1.0490)	Top 1-err 32.0000 (37.0000)
# * Epoch: [11/300]	 Top 1-err 37.172  Top 5-err 3.614	 Train Loss 1.053
# Test (on val set): [11/300][0/100]	Time 0.169 (0.169)	Loss 1.2038 (1.2038)	Top 1-err 39.0000 (39.0000)
# * Epoch: [11/300]	 Top 1-err 38.060  Top 5-err 3.700	 Test Loss 1.087
# Current best accuracy (top-1 and 5 error): 38.06 3.7
# Epoch: [12/300][0/500]	LR: 0.100000	Time 0.172 (0.172)	Loss 1.0941 (1.0941)	Top 1-err 39.0000 (39.0000)
# Epoch: [12/300][100/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 0.9945 (1.0433)	Top 1-err 43.0000 (36.6634)
# Epoch: [12/300][200/500]	LR: 0.100000	Time 0.030 (0.011)	Loss 0.9812 (1.0328)	Top 1-err 33.0000 (36.4577)
# Epoch: [12/300][300/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 0.7915 (1.0422)	Top 1-err 28.0000 (36.7342)
# Epoch: [12/300][400/500]	LR: 0.100000	Time 0.018 (0.011)	Loss 0.8443 (1.0413)	Top 1-err 30.0000 (36.7581)
# * Epoch: [12/300]	 Top 1-err 36.816  Top 5-err 3.588	 Train Loss 1.042
# Test (on val set): [12/300][0/100]	Time 0.154 (0.154)	Loss 1.0683 (1.0683)	Top 1-err 41.0000 (41.0000)
# * Epoch: [12/300]	 Top 1-err 37.070  Top 5-err 3.330	 Test Loss 1.057
# Current best accuracy (top-1 and 5 error): 37.07 3.33
# Epoch: [13/300][0/500]	LR: 0.100000	Time 0.181 (0.181)	Loss 0.9794 (0.9794)	Top 1-err 42.0000 (42.0000)
# Epoch: [13/300][100/500]	LR: 0.100000	Time 0.026 (0.012)	Loss 0.9445 (1.0279)	Top 1-err 26.0000 (36.2079)
# Epoch: [13/300][200/500]	LR: 0.100000	Time 0.013 (0.011)	Loss 1.0306 (1.0273)	Top 1-err 33.0000 (36.3532)
# Epoch: [13/300][300/500]	LR: 0.100000	Time 0.017 (0.011)	Loss 1.1594 (1.0298)	Top 1-err 44.0000 (36.4286)
# Epoch: [13/300][400/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9598 (1.0330)	Top 1-err 34.0000 (36.4813)
# * Epoch: [13/300]	 Top 1-err 36.432  Top 5-err 3.398	 Train Loss 1.035
# Test (on val set): [13/300][0/100]	Time 0.163 (0.163)	Loss 1.4575 (1.4575)	Top 1-err 49.0000 (49.0000)
# * Epoch: [13/300]	 Top 1-err 37.960  Top 5-err 3.310	 Test Loss 1.108
# Current best accuracy (top-1 and 5 error): 37.07 3.33
# Epoch: [14/300][0/500]	LR: 0.100000	Time 0.178 (0.178)	Loss 1.0131 (1.0131)	Top 1-err 38.0000 (38.0000)
# Epoch: [14/300][100/500]	LR: 0.100000	Time 0.003 (0.012)	Loss 0.8357 (1.0126)	Top 1-err 29.0000 (35.6436)
# Epoch: [14/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9576 (1.0193)	Top 1-err 33.0000 (35.8259)
# Epoch: [14/300][300/500]	LR: 0.100000	Time 0.007 (0.011)	Loss 0.8786 (1.0251)	Top 1-err 28.0000 (35.9867)
# Epoch: [14/300][400/500]	LR: 0.100000	Time 0.009 (0.011)	Loss 1.0392 (1.0212)	Top 1-err 35.0000 (35.9850)
# * Epoch: [14/300]	 Top 1-err 36.086  Top 5-err 3.394	 Train Loss 1.022
# Test (on val set): [14/300][0/100]	Time 0.149 (0.149)	Loss 1.0753 (1.0753)	Top 1-err 31.0000 (31.0000)
# * Epoch: [14/300]	 Top 1-err 35.550  Top 5-err 3.230	 Test Loss 1.033
# Current best accuracy (top-1 and 5 error): 35.55 3.23
# Epoch: [15/300][0/500]	LR: 0.100000	Time 0.177 (0.177)	Loss 1.0488 (1.0488)	Top 1-err 37.0000 (37.0000)
# Epoch: [15/300][100/500]	LR: 0.100000	Time 0.004 (0.012)	Loss 1.1483 (1.0315)	Top 1-err 44.0000 (36.0000)
# Epoch: [15/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9898 (1.0108)	Top 1-err 37.0000 (35.2587)
# Epoch: [15/300][300/500]	LR: 0.100000	Time 0.005 (0.011)	Loss 1.0029 (1.0136)	Top 1-err 36.0000 (35.6179)
# Epoch: [15/300][400/500]	LR: 0.100000	Time 0.025 (0.010)	Loss 1.0784 (1.0116)	Top 1-err 37.0000 (35.6035)
# * Epoch: [15/300]	 Top 1-err 35.624  Top 5-err 3.198	 Train Loss 1.014
# Test (on val set): [15/300][0/100]	Time 0.152 (0.152)	Loss 0.9034 (0.9034)	Top 1-err 32.0000 (32.0000)
# * Epoch: [15/300]	 Top 1-err 39.220  Top 5-err 3.730	 Test Loss 1.116
# Current best accuracy (top-1 and 5 error): 35.55 3.23
# Epoch: [16/300][0/500]	LR: 0.100000	Time 0.166 (0.166)	Loss 1.2474 (1.2474)	Top 1-err 41.0000 (41.0000)
# Epoch: [16/300][100/500]	LR: 0.100000	Time 0.005 (0.012)	Loss 1.1501 (1.0042)	Top 1-err 35.0000 (35.2574)
# Epoch: [16/300][200/500]	LR: 0.100000	Time 0.026 (0.011)	Loss 1.0441 (1.0069)	Top 1-err 37.0000 (35.6070)
# Epoch: [16/300][300/500]	LR: 0.100000	Time 0.011 (0.010)	Loss 1.1503 (1.0093)	Top 1-err 37.0000 (35.6113)
# Epoch: [16/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.0362 (1.0140)	Top 1-err 32.0000 (35.7406)
# * Epoch: [16/300]	 Top 1-err 35.658  Top 5-err 3.200	 Train Loss 1.011
# Test (on val set): [16/300][0/100]	Time 0.128 (0.128)	Loss 1.1522 (1.1522)	Top 1-err 41.0000 (41.0000)
# * Epoch: [16/300]	 Top 1-err 35.600  Top 5-err 3.100	 Test Loss 1.029
# Current best accuracy (top-1 and 5 error): 35.55 3.23
# Epoch: [17/300][0/500]	LR: 0.100000	Time 0.181 (0.181)	Loss 1.0933 (1.0933)	Top 1-err 39.0000 (39.0000)
# Epoch: [17/300][100/500]	LR: 0.100000	Time 0.003 (0.012)	Loss 0.9793 (0.9847)	Top 1-err 30.0000 (34.5149)
# Epoch: [17/300][200/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 1.0858 (0.9970)	Top 1-err 33.0000 (35.2189)
# Epoch: [17/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.2694 (1.0006)	Top 1-err 49.0000 (35.3322)
# Epoch: [17/300][400/500]	LR: 0.100000	Time 0.005 (0.010)	Loss 0.8808 (1.0032)	Top 1-err 32.0000 (35.4165)
# * Epoch: [17/300]	 Top 1-err 35.362  Top 5-err 3.316	 Train Loss 1.003
# Test (on val set): [17/300][0/100]	Time 0.136 (0.136)	Loss 0.8296 (0.8296)	Top 1-err 32.0000 (32.0000)
# * Epoch: [17/300]	 Top 1-err 35.260  Top 5-err 3.000	 Test Loss 1.015
# Current best accuracy (top-1 and 5 error): 35.26 3.0
# Epoch: [18/300][0/500]	LR: 0.100000	Time 0.172 (0.172)	Loss 0.8168 (0.8168)	Top 1-err 30.0000 (30.0000)
# Epoch: [18/300][100/500]	LR: 0.100000	Time 0.003 (0.012)	Loss 0.8795 (0.9841)	Top 1-err 30.0000 (34.4059)
# Epoch: [18/300][200/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 1.1271 (1.0054)	Top 1-err 38.0000 (35.3433)
# Epoch: [18/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.1145 (1.0063)	Top 1-err 37.0000 (35.3754)
# Epoch: [18/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.0259 (1.0039)	Top 1-err 33.0000 (35.2918)
# * Epoch: [18/300]	 Top 1-err 35.086  Top 5-err 3.286	 Train Loss 0.998
# Test (on val set): [18/300][0/100]	Time 0.153 (0.153)	Loss 1.2071 (1.2071)	Top 1-err 43.0000 (43.0000)
# * Epoch: [18/300]	 Top 1-err 36.180  Top 5-err 3.040	 Test Loss 1.055
# Current best accuracy (top-1 and 5 error): 35.26 3.0
# Epoch: [19/300][0/500]	LR: 0.100000	Time 0.171 (0.171)	Loss 1.1078 (1.1078)	Top 1-err 42.0000 (42.0000)
# Epoch: [19/300][100/500]	LR: 0.100000	Time 0.010 (0.011)	Loss 0.8820 (0.9845)	Top 1-err 31.0000 (34.2871)
# Epoch: [19/300][200/500]	LR: 0.100000	Time 0.005 (0.011)	Loss 1.0370 (0.9887)	Top 1-err 41.0000 (34.3333)
# Epoch: [19/300][300/500]	LR: 0.100000	Time 0.006 (0.011)	Loss 0.8342 (0.9923)	Top 1-err 34.0000 (34.3887)
# Epoch: [19/300][400/500]	LR: 0.100000	Time 0.006 (0.010)	Loss 1.1992 (0.9953)	Top 1-err 44.0000 (34.4888)
# * Epoch: [19/300]	 Top 1-err 34.420  Top 5-err 3.154	 Train Loss 0.990
# Test (on val set): [19/300][0/100]	Time 0.149 (0.149)	Loss 1.4296 (1.4296)	Top 1-err 43.0000 (43.0000)
# * Epoch: [19/300]	 Top 1-err 36.210  Top 5-err 2.910	 Test Loss 1.045
# Current best accuracy (top-1 and 5 error): 35.26 3.0
# Epoch: [20/300][0/500]	LR: 0.100000	Time 0.171 (0.171)	Loss 1.2219 (1.2219)	Top 1-err 42.0000 (42.0000)
# Epoch: [20/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9154 (0.9932)	Top 1-err 32.0000 (34.9703)
# Epoch: [20/300][200/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 0.8402 (0.9969)	Top 1-err 27.0000 (35.0448)
# Epoch: [20/300][300/500]	LR: 0.100000	Time 0.005 (0.010)	Loss 1.0514 (0.9874)	Top 1-err 39.0000 (34.8372)
# Epoch: [20/300][400/500]	LR: 0.100000	Time 0.006 (0.010)	Loss 0.9894 (0.9903)	Top 1-err 33.0000 (34.8628)
# * Epoch: [20/300]	 Top 1-err 34.766  Top 5-err 3.070	 Train Loss 0.987
# Test (on val set): [20/300][0/100]	Time 0.144 (0.144)	Loss 0.9963 (0.9963)	Top 1-err 31.0000 (31.0000)
# * Epoch: [20/300]	 Top 1-err 36.370  Top 5-err 3.040	 Test Loss 1.065
# Current best accuracy (top-1 and 5 error): 35.26 3.0
# Epoch: [21/300][0/500]	LR: 0.100000	Time 0.175 (0.175)	Loss 0.8236 (0.8236)	Top 1-err 27.0000 (27.0000)
# Epoch: [21/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.8870 (0.9709)	Top 1-err 27.0000 (34.0594)
# Epoch: [21/300][200/500]	LR: 0.100000	Time 0.005 (0.011)	Loss 1.1196 (0.9801)	Top 1-err 36.0000 (34.3234)
# Epoch: [21/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.7603 (0.9763)	Top 1-err 32.0000 (34.3223)
# Epoch: [21/300][400/500]	LR: 0.100000	Time 0.006 (0.010)	Loss 1.1634 (0.9829)	Top 1-err 40.0000 (34.4264)
# * Epoch: [21/300]	 Top 1-err 34.426  Top 5-err 3.254	 Train Loss 0.981
# Test (on val set): [21/300][0/100]	Time 0.135 (0.135)	Loss 1.0835 (1.0835)	Top 1-err 41.0000 (41.0000)
# * Epoch: [21/300]	 Top 1-err 35.670  Top 5-err 2.920	 Test Loss 1.044
# Current best accuracy (top-1 and 5 error): 35.26 3.0
# Epoch: [22/300][0/500]	LR: 0.100000	Time 0.155 (0.155)	Loss 0.8810 (0.8810)	Top 1-err 33.0000 (33.0000)
# Epoch: [22/300][100/500]	LR: 0.100000	Time 0.016 (0.011)	Loss 1.0944 (0.9590)	Top 1-err 34.0000 (33.7327)
# Epoch: [22/300][200/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.0743 (0.9748)	Top 1-err 36.0000 (34.1493)
# Epoch: [22/300][300/500]	LR: 0.100000	Time 0.003 (0.010)	Loss 0.9824 (0.9711)	Top 1-err 35.0000 (34.1096)
# Epoch: [22/300][400/500]	LR: 0.100000	Time 0.010 (0.010)	Loss 1.1241 (0.9764)	Top 1-err 34.0000 (34.2219)
# * Epoch: [22/300]	 Top 1-err 34.244  Top 5-err 2.984	 Train Loss 0.975
# Test (on val set): [22/300][0/100]	Time 0.148 (0.148)	Loss 1.0036 (1.0036)	Top 1-err 34.0000 (34.0000)
# * Epoch: [22/300]	 Top 1-err 35.430  Top 5-err 3.040	 Test Loss 1.036
# Current best accuracy (top-1 and 5 error): 35.26 3.0
# Epoch: [23/300][0/500]	LR: 0.100000	Time 0.173 (0.173)	Loss 1.0629 (1.0629)	Top 1-err 33.0000 (33.0000)
# Epoch: [23/300][100/500]	LR: 0.100000	Time 0.021 (0.012)	Loss 0.9459 (0.9534)	Top 1-err 39.0000 (33.9802)
# Epoch: [23/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.0086 (0.9632)	Top 1-err 39.0000 (34.0995)
# Epoch: [23/300][300/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 1.0423 (0.9712)	Top 1-err 35.0000 (34.2724)
# Epoch: [23/300][400/500]	LR: 0.100000	Time 0.031 (0.010)	Loss 0.9673 (0.9740)	Top 1-err 39.0000 (34.2394)
# * Epoch: [23/300]	 Top 1-err 34.128  Top 5-err 2.990	 Train Loss 0.973
# Test (on val set): [23/300][0/100]	Time 0.128 (0.128)	Loss 1.0056 (1.0056)	Top 1-err 37.0000 (37.0000)
# * Epoch: [23/300]	 Top 1-err 36.800  Top 5-err 3.260	 Test Loss 1.081
# Current best accuracy (top-1 and 5 error): 35.26 3.0
# Epoch: [24/300][0/500]	LR: 0.100000	Time 0.187 (0.187)	Loss 0.9609 (0.9609)	Top 1-err 39.0000 (39.0000)
# Epoch: [24/300][100/500]	LR: 0.100000	Time 0.022 (0.012)	Loss 0.9593 (0.9653)	Top 1-err 36.0000 (33.9307)
# Epoch: [24/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.0955 (0.9689)	Top 1-err 41.0000 (33.8706)
# Epoch: [24/300][300/500]	LR: 0.100000	Time 0.013 (0.011)	Loss 0.9161 (0.9753)	Top 1-err 33.0000 (34.0199)
# Epoch: [24/300][400/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.0196 (0.9706)	Top 1-err 37.0000 (33.9726)
# * Epoch: [24/300]	 Top 1-err 33.872  Top 5-err 2.964	 Train Loss 0.967
# Test (on val set): [24/300][0/100]	Time 0.139 (0.139)	Loss 1.1124 (1.1124)	Top 1-err 40.0000 (40.0000)
# * Epoch: [24/300]	 Top 1-err 34.590  Top 5-err 2.740	 Test Loss 0.987
# Current best accuracy (top-1 and 5 error): 34.59 2.74
# Epoch: [25/300][0/500]	LR: 0.100000	Time 0.174 (0.174)	Loss 1.1664 (1.1664)	Top 1-err 35.0000 (35.0000)
# Epoch: [25/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9241 (0.9740)	Top 1-err 33.0000 (34.2475)
# Epoch: [25/300][200/500]	LR: 0.100000	Time 0.008 (0.011)	Loss 1.0349 (0.9727)	Top 1-err 33.0000 (34.0348)
# Epoch: [25/300][300/500]	LR: 0.100000	Time 0.034 (0.011)	Loss 0.8350 (0.9690)	Top 1-err 30.0000 (34.0797)
# Epoch: [25/300][400/500]	LR: 0.100000	Time 0.007 (0.010)	Loss 1.0403 (0.9700)	Top 1-err 35.0000 (34.1845)
# * Epoch: [25/300]	 Top 1-err 34.060  Top 5-err 3.046	 Train Loss 0.967
# Test (on val set): [25/300][0/100]	Time 0.153 (0.153)	Loss 0.8729 (0.8729)	Top 1-err 28.0000 (28.0000)
# * Epoch: [25/300]	 Top 1-err 36.610  Top 5-err 3.150	 Test Loss 1.054
# Current best accuracy (top-1 and 5 error): 34.59 2.74
# Epoch: [26/300][0/500]	LR: 0.100000	Time 0.171 (0.171)	Loss 0.9252 (0.9252)	Top 1-err 33.0000 (33.0000)
# Epoch: [26/300][100/500]	LR: 0.100000	Time 0.008 (0.011)	Loss 1.1179 (0.9645)	Top 1-err 38.0000 (34.1287)
# Epoch: [26/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9533 (0.9553)	Top 1-err 32.0000 (33.5274)
# Epoch: [26/300][300/500]	LR: 0.100000	Time 0.003 (0.010)	Loss 1.0600 (0.9589)	Top 1-err 44.0000 (33.6611)
# Epoch: [26/300][400/500]	LR: 0.100000	Time 0.029 (0.010)	Loss 0.8469 (0.9584)	Top 1-err 27.0000 (33.5835)
# * Epoch: [26/300]	 Top 1-err 33.646  Top 5-err 2.924	 Train Loss 0.957
# Test (on val set): [26/300][0/100]	Time 0.155 (0.155)	Loss 0.7663 (0.7663)	Top 1-err 31.0000 (31.0000)
# * Epoch: [26/300]	 Top 1-err 33.990  Top 5-err 2.850	 Test Loss 0.981
# Current best accuracy (top-1 and 5 error): 33.99 2.85
# Epoch: [27/300][0/500]	LR: 0.100000	Time 0.174 (0.174)	Loss 0.8673 (0.8673)	Top 1-err 27.0000 (27.0000)
# Epoch: [27/300][100/500]	LR: 0.100000	Time 0.005 (0.011)	Loss 1.0478 (0.9433)	Top 1-err 33.0000 (33.1881)
# Epoch: [27/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.6860 (0.9531)	Top 1-err 23.0000 (33.3532)
# Epoch: [27/300][300/500]	LR: 0.100000	Time 0.003 (0.010)	Loss 0.9692 (0.9511)	Top 1-err 36.0000 (33.2292)
# Epoch: [27/300][400/500]	LR: 0.100000	Time 0.019 (0.010)	Loss 0.8210 (0.9580)	Top 1-err 32.0000 (33.5711)
# * Epoch: [27/300]	 Top 1-err 33.648  Top 5-err 2.910	 Train Loss 0.957
# Test (on val set): [27/300][0/100]	Time 0.168 (0.168)	Loss 1.1097 (1.1097)	Top 1-err 43.0000 (43.0000)
# * Epoch: [27/300]	 Top 1-err 34.880  Top 5-err 2.740	 Test Loss 0.998
# Current best accuracy (top-1 and 5 error): 33.99 2.85
# Epoch: [28/300][0/500]	LR: 0.100000	Time 0.158 (0.158)	Loss 1.0561 (1.0561)	Top 1-err 37.0000 (37.0000)
# Epoch: [28/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.0085 (0.9497)	Top 1-err 37.0000 (33.3663)
# Epoch: [28/300][200/500]	LR: 0.100000	Time 0.022 (0.011)	Loss 1.1147 (0.9464)	Top 1-err 43.0000 (33.1493)
# Epoch: [28/300][300/500]	LR: 0.100000	Time 0.009 (0.011)	Loss 0.9089 (0.9469)	Top 1-err 29.0000 (33.0598)
# Epoch: [28/300][400/500]	LR: 0.100000	Time 0.005 (0.010)	Loss 0.9771 (0.9489)	Top 1-err 31.0000 (33.0100)
# * Epoch: [28/300]	 Top 1-err 33.234  Top 5-err 2.870	 Train Loss 0.950
# Test (on val set): [28/300][0/100]	Time 0.140 (0.140)	Loss 0.8702 (0.8702)	Top 1-err 29.0000 (29.0000)
# * Epoch: [28/300]	 Top 1-err 34.870  Top 5-err 2.900	 Test Loss 0.990
# Current best accuracy (top-1 and 5 error): 33.99 2.85
# Epoch: [29/300][0/500]	LR: 0.100000	Time 0.172 (0.172)	Loss 1.0423 (1.0423)	Top 1-err 41.0000 (41.0000)
# Epoch: [29/300][100/500]	LR: 0.100000	Time 0.012 (0.011)	Loss 0.8907 (0.9541)	Top 1-err 34.0000 (33.1485)
# Epoch: [29/300][200/500]	LR: 0.100000	Time 0.022 (0.011)	Loss 0.8701 (0.9501)	Top 1-err 32.0000 (33.0398)
# Epoch: [29/300][300/500]	LR: 0.100000	Time 0.007 (0.011)	Loss 0.9970 (0.9496)	Top 1-err 37.0000 (33.2591)
# Epoch: [29/300][400/500]	LR: 0.100000	Time 0.013 (0.010)	Loss 0.9001 (0.9538)	Top 1-err 35.0000 (33.4713)
# * Epoch: [29/300]	 Top 1-err 33.340  Top 5-err 2.926	 Train Loss 0.951
# Test (on val set): [29/300][0/100]	Time 0.150 (0.150)	Loss 0.8927 (0.8927)	Top 1-err 34.0000 (34.0000)
# * Epoch: [29/300]	 Top 1-err 36.070  Top 5-err 3.100	 Test Loss 1.053
# Current best accuracy (top-1 and 5 error): 33.99 2.85
# Epoch: [30/300][0/500]	LR: 0.100000	Time 0.176 (0.176)	Loss 0.9669 (0.9669)	Top 1-err 35.0000 (35.0000)
# Epoch: [30/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9486 (0.9693)	Top 1-err 30.0000 (33.4356)
# Epoch: [30/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9386 (0.9552)	Top 1-err 23.0000 (33.1940)
# Epoch: [30/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.8302 (0.9567)	Top 1-err 27.0000 (33.2757)
# Epoch: [30/300][400/500]	LR: 0.100000	Time 0.003 (0.010)	Loss 1.1707 (0.9554)	Top 1-err 39.0000 (33.3267)
# * Epoch: [30/300]	 Top 1-err 33.426  Top 5-err 2.980	 Train Loss 0.954
# Test (on val set): [30/300][0/100]	Time 0.147 (0.147)	Loss 1.1431 (1.1431)	Top 1-err 46.0000 (46.0000)
# * Epoch: [30/300]	 Top 1-err 36.620  Top 5-err 2.780	 Test Loss 1.044
# Current best accuracy (top-1 and 5 error): 33.99 2.85
# Epoch: [31/300][0/500]	LR: 0.100000	Time 0.155 (0.155)	Loss 0.9400 (0.9400)	Top 1-err 28.0000 (28.0000)
# Epoch: [31/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9310 (0.9452)	Top 1-err 31.0000 (33.4356)
# Epoch: [31/300][200/500]	LR: 0.100000	Time 0.031 (0.011)	Loss 1.0334 (0.9485)	Top 1-err 32.0000 (33.3731)
# Epoch: [31/300][300/500]	LR: 0.100000	Time 0.014 (0.011)	Loss 0.8070 (0.9476)	Top 1-err 33.0000 (33.2093)
# Epoch: [31/300][400/500]	LR: 0.100000	Time 0.019 (0.010)	Loss 1.0223 (0.9456)	Top 1-err 40.0000 (33.2394)
# * Epoch: [31/300]	 Top 1-err 33.254  Top 5-err 2.864	 Train Loss 0.946
# Test (on val set): [31/300][0/100]	Time 0.154 (0.154)	Loss 1.1061 (1.1061)	Top 1-err 39.0000 (39.0000)
# * Epoch: [31/300]	 Top 1-err 32.960  Top 5-err 2.540	 Test Loss 0.962
# Current best accuracy (top-1 and 5 error): 32.96 2.54
# Epoch: [32/300][0/500]	LR: 0.100000	Time 0.161 (0.161)	Loss 0.7677 (0.7677)	Top 1-err 26.0000 (26.0000)
# Epoch: [32/300][100/500]	LR: 0.100000	Time 0.015 (0.012)	Loss 1.0508 (0.9351)	Top 1-err 39.0000 (32.4455)
# Epoch: [32/300][200/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 1.0105 (0.9385)	Top 1-err 36.0000 (32.7662)
# Epoch: [32/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.9084 (0.9364)	Top 1-err 30.0000 (32.8405)
# Epoch: [32/300][400/500]	LR: 0.100000	Time 0.014 (0.010)	Loss 1.1086 (0.9387)	Top 1-err 36.0000 (32.8304)
# * Epoch: [32/300]	 Top 1-err 32.996  Top 5-err 2.712	 Train Loss 0.941
# Test (on val set): [32/300][0/100]	Time 0.145 (0.145)	Loss 0.9511 (0.9511)	Top 1-err 34.0000 (34.0000)
# * Epoch: [32/300]	 Top 1-err 34.940  Top 5-err 2.840	 Test Loss 1.012
# Current best accuracy (top-1 and 5 error): 32.96 2.54
# Epoch: [33/300][0/500]	LR: 0.100000	Time 0.178 (0.178)	Loss 0.9788 (0.9788)	Top 1-err 28.0000 (28.0000)
# Epoch: [33/300][100/500]	LR: 0.100000	Time 0.012 (0.012)	Loss 0.9093 (0.9291)	Top 1-err 36.0000 (32.4455)
# Epoch: [33/300][200/500]	LR: 0.100000	Time 0.010 (0.011)	Loss 1.0113 (0.9324)	Top 1-err 36.0000 (32.8557)
# Epoch: [33/300][300/500]	LR: 0.100000	Time 0.011 (0.011)	Loss 0.7623 (0.9337)	Top 1-err 26.0000 (32.7674)
# Epoch: [33/300][400/500]	LR: 0.100000	Time 0.003 (0.010)	Loss 0.8035 (0.9372)	Top 1-err 31.0000 (32.9302)
# * Epoch: [33/300]	 Top 1-err 32.978  Top 5-err 2.900	 Train Loss 0.939
# Test (on val set): [33/300][0/100]	Time 0.150 (0.150)	Loss 0.8367 (0.8367)	Top 1-err 29.0000 (29.0000)
# * Epoch: [33/300]	 Top 1-err 33.720  Top 5-err 2.760	 Test Loss 0.981
# Current best accuracy (top-1 and 5 error): 32.96 2.54
# Epoch: [34/300][0/500]	LR: 0.100000	Time 0.177 (0.177)	Loss 0.9420 (0.9420)	Top 1-err 34.0000 (34.0000)
# Epoch: [34/300][100/500]	LR: 0.100000	Time 0.010 (0.012)	Loss 0.9491 (0.9306)	Top 1-err 37.0000 (32.9010)
# Epoch: [34/300][200/500]	LR: 0.100000	Time 0.021 (0.011)	Loss 0.8535 (0.9384)	Top 1-err 30.0000 (33.0299)
# Epoch: [34/300][300/500]	LR: 0.100000	Time 0.015 (0.011)	Loss 0.7427 (0.9406)	Top 1-err 24.0000 (32.8638)
# Epoch: [34/300][400/500]	LR: 0.100000	Time 0.024 (0.010)	Loss 0.6787 (0.9394)	Top 1-err 24.0000 (32.7880)
# * Epoch: [34/300]	 Top 1-err 32.708  Top 5-err 2.888	 Train Loss 0.936
# Test (on val set): [34/300][0/100]	Time 0.152 (0.152)	Loss 1.0478 (1.0478)	Top 1-err 34.0000 (34.0000)
# * Epoch: [34/300]	 Top 1-err 34.340  Top 5-err 2.600	 Test Loss 0.989
# Current best accuracy (top-1 and 5 error): 32.96 2.54
# Epoch: [35/300][0/500]	LR: 0.100000	Time 0.170 (0.170)	Loss 1.1011 (1.1011)	Top 1-err 37.0000 (37.0000)
# Epoch: [35/300][100/500]	LR: 0.100000	Time 0.023 (0.012)	Loss 1.0591 (0.9468)	Top 1-err 38.0000 (33.0198)
# Epoch: [35/300][200/500]	LR: 0.100000	Time 0.028 (0.011)	Loss 0.9988 (0.9350)	Top 1-err 34.0000 (32.8905)
# Epoch: [35/300][300/500]	LR: 0.100000	Time 0.003 (0.010)	Loss 1.0905 (0.9320)	Top 1-err 42.0000 (32.7110)
# Epoch: [35/300][400/500]	LR: 0.100000	Time 0.006 (0.010)	Loss 0.9603 (0.9354)	Top 1-err 34.0000 (32.8180)
# * Epoch: [35/300]	 Top 1-err 32.806  Top 5-err 2.768	 Train Loss 0.936
# Test (on val set): [35/300][0/100]	Time 0.154 (0.154)	Loss 0.9817 (0.9817)	Top 1-err 33.0000 (33.0000)
# * Epoch: [35/300]	 Top 1-err 33.970  Top 5-err 2.620	 Test Loss 0.973
# Current best accuracy (top-1 and 5 error): 32.96 2.54
# Epoch: [36/300][0/500]	LR: 0.100000	Time 0.168 (0.168)	Loss 0.9175 (0.9175)	Top 1-err 27.0000 (27.0000)
# Epoch: [36/300][100/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 0.9122 (0.9258)	Top 1-err 29.0000 (32.5347)
# Epoch: [36/300][200/500]	LR: 0.100000	Time 0.027 (0.011)	Loss 0.9234 (0.9247)	Top 1-err 30.0000 (32.5423)
# Epoch: [36/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.0131 (0.9304)	Top 1-err 37.0000 (32.7907)
# Epoch: [36/300][400/500]	LR: 0.100000	Time 0.010 (0.010)	Loss 1.0158 (0.9326)	Top 1-err 36.0000 (32.8155)
# * Epoch: [36/300]	 Top 1-err 32.632  Top 5-err 2.618	 Train Loss 0.932
# Test (on val set): [36/300][0/100]	Time 0.157 (0.157)	Loss 0.7437 (0.7437)	Top 1-err 30.0000 (30.0000)
# * Epoch: [36/300]	 Top 1-err 33.430  Top 5-err 2.820	 Test Loss 0.987
# Current best accuracy (top-1 and 5 error): 32.96 2.54
# Epoch: [37/300][0/500]	LR: 0.100000	Time 0.170 (0.170)	Loss 1.0987 (1.0987)	Top 1-err 38.0000 (38.0000)
# Epoch: [37/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.0777 (0.9448)	Top 1-err 40.0000 (33.2277)
# Epoch: [37/300][200/500]	LR: 0.100000	Time 0.005 (0.011)	Loss 0.7562 (0.9404)	Top 1-err 27.0000 (32.9652)
# Epoch: [37/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.7398 (0.9406)	Top 1-err 20.0000 (32.9336)
# Epoch: [37/300][400/500]	LR: 0.100000	Time 0.033 (0.010)	Loss 1.1421 (0.9367)	Top 1-err 41.0000 (32.6708)
# * Epoch: [37/300]	 Top 1-err 32.690  Top 5-err 2.696	 Train Loss 0.935
# Test (on val set): [37/300][0/100]	Time 0.155 (0.155)	Loss 0.8713 (0.8713)	Top 1-err 33.0000 (33.0000)
# * Epoch: [37/300]	 Top 1-err 33.920  Top 5-err 3.000	 Test Loss 1.002
# Current best accuracy (top-1 and 5 error): 32.96 2.54
# Epoch: [38/300][0/500]	LR: 0.100000	Time 0.170 (0.170)	Loss 0.8720 (0.8720)	Top 1-err 31.0000 (31.0000)
# Epoch: [38/300][100/500]	LR: 0.100000	Time 0.006 (0.011)	Loss 1.0724 (0.9260)	Top 1-err 35.0000 (32.1782)
# Epoch: [38/300][200/500]	LR: 0.100000	Time 0.006 (0.011)	Loss 0.8839 (0.9230)	Top 1-err 33.0000 (32.2736)
# Epoch: [38/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.7696 (0.9305)	Top 1-err 26.0000 (32.4983)
# Epoch: [38/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.9992 (0.9234)	Top 1-err 32.0000 (32.2419)
# * Epoch: [38/300]	 Top 1-err 32.402  Top 5-err 2.762	 Train Loss 0.928
# Test (on val set): [38/300][0/100]	Time 0.143 (0.143)	Loss 0.8878 (0.8878)	Top 1-err 27.0000 (27.0000)
# * Epoch: [38/300]	 Top 1-err 33.730  Top 5-err 2.500	 Test Loss 0.967
# Current best accuracy (top-1 and 5 error): 32.96 2.54
# Epoch: [39/300][0/500]	LR: 0.100000	Time 0.172 (0.172)	Loss 1.0176 (1.0176)	Top 1-err 38.0000 (38.0000)
# Epoch: [39/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.8797 (0.9394)	Top 1-err 39.0000 (33.1584)
# Epoch: [39/300][200/500]	LR: 0.100000	Time 0.021 (0.011)	Loss 1.0527 (0.9356)	Top 1-err 37.0000 (32.8060)
# Epoch: [39/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.7488 (0.9301)	Top 1-err 30.0000 (32.6013)
# Epoch: [39/300][400/500]	LR: 0.100000	Time 0.016 (0.010)	Loss 0.9729 (0.9358)	Top 1-err 35.0000 (32.7756)
# * Epoch: [39/300]	 Top 1-err 32.686  Top 5-err 2.778	 Train Loss 0.932
# Test (on val set): [39/300][0/100]	Time 0.148 (0.148)	Loss 1.0597 (1.0597)	Top 1-err 39.0000 (39.0000)
# * Epoch: [39/300]	 Top 1-err 36.090  Top 5-err 2.910	 Test Loss 1.052
# Current best accuracy (top-1 and 5 error): 32.96 2.54
# Epoch: [40/300][0/500]	LR: 0.100000	Time 0.174 (0.174)	Loss 1.1979 (1.1979)	Top 1-err 40.0000 (40.0000)
# Epoch: [40/300][100/500]	LR: 0.100000	Time 0.004 (0.012)	Loss 0.9437 (0.9171)	Top 1-err 30.0000 (31.9901)
# Epoch: [40/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9909 (0.9232)	Top 1-err 37.0000 (32.3483)
# Epoch: [40/300][300/500]	LR: 0.100000	Time 0.028 (0.011)	Loss 1.0834 (0.9283)	Top 1-err 36.0000 (32.4385)
# Epoch: [40/300][400/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.8374 (0.9275)	Top 1-err 28.0000 (32.3815)
# * Epoch: [40/300]	 Top 1-err 32.458  Top 5-err 2.838	 Train Loss 0.930
# Test (on val set): [40/300][0/100]	Time 0.145 (0.145)	Loss 0.9750 (0.9750)	Top 1-err 33.0000 (33.0000)
# * Epoch: [40/300]	 Top 1-err 33.880  Top 5-err 2.720	 Test Loss 0.977
# Current best accuracy (top-1 and 5 error): 32.96 2.54
# Epoch: [41/300][0/500]	LR: 0.100000	Time 0.191 (0.191)	Loss 0.9987 (0.9987)	Top 1-err 39.0000 (39.0000)
# Epoch: [41/300][100/500]	LR: 0.100000	Time 0.006 (0.011)	Loss 0.9320 (0.9050)	Top 1-err 35.0000 (31.6139)
# Epoch: [41/300][200/500]	LR: 0.100000	Time 0.011 (0.011)	Loss 0.9813 (0.9135)	Top 1-err 40.0000 (32.1095)
# Epoch: [41/300][300/500]	LR: 0.100000	Time 0.006 (0.011)	Loss 0.8651 (0.9199)	Top 1-err 35.0000 (32.3854)
# Epoch: [41/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.0528 (0.9274)	Top 1-err 37.0000 (32.4613)
# * Epoch: [41/300]	 Top 1-err 32.424  Top 5-err 2.786	 Train Loss 0.926
# Test (on val set): [41/300][0/100]	Time 0.136 (0.136)	Loss 0.8999 (0.8999)	Top 1-err 35.0000 (35.0000)
# * Epoch: [41/300]	 Top 1-err 32.770  Top 5-err 2.490	 Test Loss 0.956
# Current best accuracy (top-1 and 5 error): 32.77 2.49
# Epoch: [42/300][0/500]	LR: 0.100000	Time 0.185 (0.185)	Loss 0.8933 (0.8933)	Top 1-err 28.0000 (28.0000)
# Epoch: [42/300][100/500]	LR: 0.100000	Time 0.004 (0.012)	Loss 0.9360 (0.9246)	Top 1-err 31.0000 (32.0693)
# Epoch: [42/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.8575 (0.9195)	Top 1-err 35.0000 (32.3682)
# Epoch: [42/300][300/500]	LR: 0.100000	Time 0.033 (0.011)	Loss 1.0365 (0.9220)	Top 1-err 37.0000 (32.4684)
# Epoch: [42/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.9802 (0.9144)	Top 1-err 34.0000 (32.0474)
# * Epoch: [42/300]	 Top 1-err 32.052  Top 5-err 2.606	 Train Loss 0.914
# Test (on val set): [42/300][0/100]	Time 0.144 (0.144)	Loss 1.0899 (1.0899)	Top 1-err 35.0000 (35.0000)
# * Epoch: [42/300]	 Top 1-err 35.700  Top 5-err 3.070	 Test Loss 1.035
# Current best accuracy (top-1 and 5 error): 32.77 2.49
# Epoch: [43/300][0/500]	LR: 0.100000	Time 0.153 (0.153)	Loss 0.7821 (0.7821)	Top 1-err 29.0000 (29.0000)
# Epoch: [43/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.1823 (0.9239)	Top 1-err 44.0000 (32.5842)
# Epoch: [43/300][200/500]	LR: 0.100000	Time 0.009 (0.011)	Loss 0.9706 (0.9178)	Top 1-err 30.0000 (32.0149)
# Epoch: [43/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.8457 (0.9195)	Top 1-err 27.0000 (32.1196)
# Epoch: [43/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.9042 (0.9217)	Top 1-err 33.0000 (32.3117)
# * Epoch: [43/300]	 Top 1-err 32.450  Top 5-err 2.660	 Train Loss 0.925
# Test (on val set): [43/300][0/100]	Time 0.132 (0.132)	Loss 0.9690 (0.9690)	Top 1-err 30.0000 (30.0000)
# * Epoch: [43/300]	 Top 1-err 35.660  Top 5-err 2.700	 Test Loss 1.041
# Current best accuracy (top-1 and 5 error): 32.77 2.49
# Epoch: [44/300][0/500]	LR: 0.100000	Time 0.176 (0.176)	Loss 1.0706 (1.0706)	Top 1-err 41.0000 (41.0000)
# Epoch: [44/300][100/500]	LR: 0.100000	Time 0.029 (0.012)	Loss 0.9384 (0.9019)	Top 1-err 35.0000 (31.7525)
# Epoch: [44/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.0057 (0.9112)	Top 1-err 34.0000 (31.9154)
# Epoch: [44/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.8441 (0.9146)	Top 1-err 33.0000 (32.2292)
# Epoch: [44/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.0317 (0.9170)	Top 1-err 38.0000 (32.2918)
# * Epoch: [44/300]	 Top 1-err 32.358  Top 5-err 2.640	 Train Loss 0.919
# Test (on val set): [44/300][0/100]	Time 0.138 (0.138)	Loss 1.0958 (1.0958)	Top 1-err 37.0000 (37.0000)
# * Epoch: [44/300]	 Top 1-err 35.560  Top 5-err 3.380	 Test Loss 1.041
# Current best accuracy (top-1 and 5 error): 32.77 2.49
# Epoch: [45/300][0/500]	LR: 0.100000	Time 0.172 (0.172)	Loss 1.0370 (1.0370)	Top 1-err 37.0000 (37.0000)
# Epoch: [45/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.7974 (0.9023)	Top 1-err 29.0000 (31.3960)
# Epoch: [45/300][200/500]	LR: 0.100000	Time 0.011 (0.011)	Loss 0.8951 (0.9143)	Top 1-err 32.0000 (31.8856)
# Epoch: [45/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.5983 (0.9183)	Top 1-err 20.0000 (32.0797)
# Epoch: [45/300][400/500]	LR: 0.100000	Time 0.030 (0.010)	Loss 0.8993 (0.9187)	Top 1-err 34.0000 (32.1771)
# * Epoch: [45/300]	 Top 1-err 32.140  Top 5-err 2.734	 Train Loss 0.919
# Test (on val set): [45/300][0/100]	Time 0.152 (0.152)	Loss 0.9936 (0.9936)	Top 1-err 31.0000 (31.0000)
# * Epoch: [45/300]	 Top 1-err 32.640  Top 5-err 2.750	 Test Loss 0.969
# Current best accuracy (top-1 and 5 error): 32.64 2.75
# Epoch: [46/300][0/500]	LR: 0.100000	Time 0.165 (0.165)	Loss 0.6771 (0.6771)	Top 1-err 21.0000 (21.0000)
# Epoch: [46/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.7019 (0.9081)	Top 1-err 26.0000 (31.6040)
# Epoch: [46/300][200/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.8928 (0.9223)	Top 1-err 31.0000 (32.1493)
# Epoch: [46/300][300/500]	LR: 0.100000	Time 0.003 (0.010)	Loss 1.0773 (0.9138)	Top 1-err 38.0000 (31.7342)
# Epoch: [46/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.8501 (0.9095)	Top 1-err 30.0000 (31.6259)
# * Epoch: [46/300]	 Top 1-err 31.670  Top 5-err 2.678	 Train Loss 0.910
# Test (on val set): [46/300][0/100]	Time 0.153 (0.153)	Loss 1.0979 (1.0979)	Top 1-err 46.0000 (46.0000)
# * Epoch: [46/300]	 Top 1-err 32.820  Top 5-err 2.640	 Test Loss 0.953
# Current best accuracy (top-1 and 5 error): 32.64 2.75
# Epoch: [47/300][0/500]	LR: 0.100000	Time 0.164 (0.164)	Loss 0.8208 (0.8208)	Top 1-err 31.0000 (31.0000)
# Epoch: [47/300][100/500]	LR: 0.100000	Time 0.008 (0.011)	Loss 1.1663 (0.9155)	Top 1-err 35.0000 (32.2178)
# Epoch: [47/300][200/500]	LR: 0.100000	Time 0.011 (0.011)	Loss 1.0211 (0.9063)	Top 1-err 38.0000 (31.7910)
# Epoch: [47/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.9690 (0.9122)	Top 1-err 32.0000 (32.0365)
# Epoch: [47/300][400/500]	LR: 0.100000	Time 0.011 (0.010)	Loss 1.0430 (0.9140)	Top 1-err 37.0000 (32.0449)
# * Epoch: [47/300]	 Top 1-err 32.092  Top 5-err 2.656	 Train Loss 0.915
# Test (on val set): [47/300][0/100]	Time 0.149 (0.149)	Loss 0.8865 (0.8865)	Top 1-err 32.0000 (32.0000)
# * Epoch: [47/300]	 Top 1-err 32.390  Top 5-err 2.400	 Test Loss 0.939
# Current best accuracy (top-1 and 5 error): 32.39 2.4
# Epoch: [48/300][0/500]	LR: 0.100000	Time 0.173 (0.173)	Loss 0.9978 (0.9978)	Top 1-err 38.0000 (38.0000)
# Epoch: [48/300][100/500]	LR: 0.100000	Time 0.023 (0.011)	Loss 0.9243 (0.9133)	Top 1-err 27.0000 (31.3168)
# Epoch: [48/300][200/500]	LR: 0.100000	Time 0.005 (0.011)	Loss 0.7203 (0.9033)	Top 1-err 22.0000 (31.1443)
# Epoch: [48/300][300/500]	LR: 0.100000	Time 0.006 (0.011)	Loss 0.7731 (0.9079)	Top 1-err 33.0000 (31.3953)
# Epoch: [48/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.9444 (0.9124)	Top 1-err 30.0000 (31.6534)
# * Epoch: [48/300]	 Top 1-err 31.686  Top 5-err 2.562	 Train Loss 0.912
# Test (on val set): [48/300][0/100]	Time 0.152 (0.152)	Loss 1.0077 (1.0077)	Top 1-err 36.0000 (36.0000)
# * Epoch: [48/300]	 Top 1-err 34.750  Top 5-err 2.720	 Test Loss 1.033
# Current best accuracy (top-1 and 5 error): 32.39 2.4
# Epoch: [49/300][0/500]	LR: 0.100000	Time 0.181 (0.181)	Loss 0.7689 (0.7689)	Top 1-err 28.0000 (28.0000)
# Epoch: [49/300][100/500]	LR: 0.100000	Time 0.027 (0.012)	Loss 0.9174 (0.9092)	Top 1-err 33.0000 (31.6733)
# Epoch: [49/300][200/500]	LR: 0.100000	Time 0.029 (0.011)	Loss 1.0265 (0.9098)	Top 1-err 36.0000 (31.8657)
# Epoch: [49/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.9433 (0.9079)	Top 1-err 32.0000 (31.8472)
# Epoch: [49/300][400/500]	LR: 0.100000	Time 0.011 (0.010)	Loss 0.7817 (0.9125)	Top 1-err 27.0000 (31.8978)
# * Epoch: [49/300]	 Top 1-err 31.926  Top 5-err 2.610	 Train Loss 0.912
# Test (on val set): [49/300][0/100]	Time 0.146 (0.146)	Loss 1.1024 (1.1024)	Top 1-err 37.0000 (37.0000)
# * Epoch: [49/300]	 Top 1-err 34.150  Top 5-err 2.730	 Test Loss 1.002
# Current best accuracy (top-1 and 5 error): 32.39 2.4
# Epoch: [50/300][0/500]	LR: 0.100000	Time 0.174 (0.174)	Loss 0.8588 (0.8588)	Top 1-err 28.0000 (28.0000)
# Epoch: [50/300][100/500]	LR: 0.100000	Time 0.032 (0.012)	Loss 0.8646 (0.9072)	Top 1-err 34.0000 (31.5743)
# Epoch: [50/300][200/500]	LR: 0.100000	Time 0.003 (0.011)	Loss 0.8596 (0.9081)	Top 1-err 31.0000 (31.7114)
# Epoch: [50/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9321 (0.9023)	Top 1-err 39.0000 (31.6545)
# Epoch: [50/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 0.9792 (0.9031)	Top 1-err 33.0000 (31.6234)
# * Epoch: [50/300]	 Top 1-err 31.770  Top 5-err 2.592	 Train Loss 0.908
# Test (on val set): [50/300][0/100]	Time 0.150 (0.150)	Loss 1.0104 (1.0104)	Top 1-err 41.0000 (41.0000)
# * Epoch: [50/300]	 Top 1-err 33.880  Top 5-err 2.670	 Test Loss 0.995
# Current best accuracy (top-1 and 5 error): 32.39 2.4
# Epoch: [51/300][0/500]	LR: 0.100000	Time 0.169 (0.169)	Loss 0.7959 (0.7959)	Top 1-err 29.0000 (29.0000)
# Epoch: [51/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 1.1379 (0.9222)	Top 1-err 40.0000 (32.6535)
# Epoch: [51/300][200/500]	LR: 0.100000	Time 0.014 (0.011)	Loss 0.7543 (0.9154)	Top 1-err 29.0000 (31.9254)
# Epoch: [51/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.0457 (0.9175)	Top 1-err 30.0000 (32.0199)
# Epoch: [51/300][400/500]	LR: 0.100000	Time 0.006 (0.010)	Loss 0.8932 (0.9154)	Top 1-err 33.0000 (32.0574)
# * Epoch: [51/300]	 Top 1-err 32.066  Top 5-err 2.698	 Train Loss 0.918
# Test (on val set): [51/300][0/100]	Time 0.154 (0.154)	Loss 0.9301 (0.9301)	Top 1-err 31.0000 (31.0000)
# * Epoch: [51/300]	 Top 1-err 32.900  Top 5-err 2.940	 Test Loss 0.959
# Current best accuracy (top-1 and 5 error): 32.39 2.4
# Epoch: [52/300][0/500]	LR: 0.100000	Time 0.156 (0.156)	Loss 0.9115 (0.9115)	Top 1-err 37.0000 (37.0000)
# Epoch: [52/300][100/500]	LR: 0.100000	Time 0.011 (0.011)	Loss 0.9198 (0.9111)	Top 1-err 34.0000 (31.7723)
# Epoch: [52/300][200/500]	LR: 0.100000	Time 0.020 (0.011)	Loss 0.7917 (0.9055)	Top 1-err 28.0000 (31.4080)
# Epoch: [52/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.7028 (0.9076)	Top 1-err 24.0000 (31.5150)
# Epoch: [52/300][400/500]	LR: 0.100000	Time 0.006 (0.010)	Loss 0.8118 (0.9123)	Top 1-err 24.0000 (31.6983)
# * Epoch: [52/300]	 Top 1-err 31.606  Top 5-err 2.566	 Train Loss 0.909
# Test (on val set): [52/300][0/100]	Time 0.152 (0.152)	Loss 0.7689 (0.7689)	Top 1-err 30.0000 (30.0000)
# * Epoch: [52/300]	 Top 1-err 32.270  Top 5-err 2.560	 Test Loss 0.943
# Current best accuracy (top-1 and 5 error): 32.27 2.56
# Epoch: [53/300][0/500]	LR: 0.100000	Time 0.163 (0.163)	Loss 0.7634 (0.7634)	Top 1-err 28.0000 (28.0000)
# Epoch: [53/300][100/500]	LR: 0.100000	Time 0.005 (0.012)	Loss 0.9045 (0.9142)	Top 1-err 34.0000 (31.5545)
# Epoch: [53/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9543 (0.9090)	Top 1-err 30.0000 (31.7363)
# Epoch: [53/300][300/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9219 (0.9087)	Top 1-err 26.0000 (31.9701)
# Epoch: [53/300][400/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9176 (0.9101)	Top 1-err 37.0000 (31.9601)
# * Epoch: [53/300]	 Top 1-err 31.980  Top 5-err 2.574	 Train Loss 0.911
# Test (on val set): [53/300][0/100]	Time 0.166 (0.166)	Loss 0.7911 (0.7911)	Top 1-err 25.0000 (25.0000)
# * Epoch: [53/300]	 Top 1-err 31.220  Top 5-err 2.220	 Test Loss 0.917
# Current best accuracy (top-1 and 5 error): 31.22 2.22
# Epoch: [54/300][0/500]	LR: 0.100000	Time 0.159 (0.159)	Loss 0.9226 (0.9226)	Top 1-err 37.0000 (37.0000)
# Epoch: [54/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9208 (0.9116)	Top 1-err 29.0000 (31.8713)
# Epoch: [54/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.7515 (0.9083)	Top 1-err 29.0000 (31.6816)
# Epoch: [54/300][300/500]	LR: 0.100000	Time 0.014 (0.011)	Loss 0.9425 (0.9101)	Top 1-err 31.0000 (31.9502)
# Epoch: [54/300][400/500]	LR: 0.100000	Time 0.012 (0.011)	Loss 1.0886 (0.9148)	Top 1-err 34.0000 (32.1446)
# * Epoch: [54/300]	 Top 1-err 32.034  Top 5-err 2.562	 Train Loss 0.914
# Test (on val set): [54/300][0/100]	Time 0.150 (0.150)	Loss 0.7742 (0.7742)	Top 1-err 21.0000 (21.0000)
# * Epoch: [54/300]	 Top 1-err 34.050  Top 5-err 2.650	 Test Loss 0.982
# Current best accuracy (top-1 and 5 error): 31.22 2.22
# Epoch: [55/300][0/500]	LR: 0.100000	Time 0.177 (0.177)	Loss 0.9078 (0.9078)	Top 1-err 33.0000 (33.0000)
# Epoch: [55/300][100/500]	LR: 0.100000	Time 0.030 (0.012)	Loss 0.9357 (0.9089)	Top 1-err 36.0000 (32.1980)
# Epoch: [55/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.9765 (0.8996)	Top 1-err 34.0000 (31.8607)
# Epoch: [55/300][300/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.0099 (0.9083)	Top 1-err 29.0000 (31.7542)
# Epoch: [55/300][400/500]	LR: 0.100000	Time 0.004 (0.010)	Loss 1.0287 (0.9088)	Top 1-err 31.0000 (31.8479)
# * Epoch: [55/300]	 Top 1-err 31.818  Top 5-err 2.556	 Train Loss 0.909
# Test (on val set): [55/300][0/100]	Time 0.159 (0.159)	Loss 0.9104 (0.9104)	Top 1-err 36.0000 (36.0000)
# * Epoch: [55/300]	 Top 1-err 32.900  Top 5-err 2.700	 Test Loss 0.966
# Current best accuracy (top-1 and 5 error): 31.22 2.22
# Epoch: [56/300][0/500]	LR: 0.100000	Time 0.170 (0.170)	Loss 0.9585 (0.9585)	Top 1-err 31.0000 (31.0000)
# Epoch: [56/300][100/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.8096 (0.9038)	Top 1-err 32.0000 (31.5446)
# Epoch: [56/300][200/500]	LR: 0.100000	Time 0.004 (0.011)	Loss 0.8496 (0.9101)	Top 1-err 31.0000 (31.6816)
# Epoch: [56/300][300/500]	LR: 0.100000	Time 0.012 (0.010)	Loss 0.7482 (0.9099)	Top 1-err 28.0000 (31.7409)
# Epoch: [56/300][400/500]	LR: 0.100000	Time 0.018 (0.010)	Loss 0.9279 (0.9106)	Top 1-err 36.0000 (31.7382)
# * Epoch: [56/300]	 Top 1-err 31.576  Top 5-err 2.610	 Train Loss 0.908
# Test (on val set): [56/300][0/100]	Time 0.160 (0.160)	Loss 1.1096 (1.1096)	Top 1-err 34.0000 (34.0000)
# * Epoch: [56/300]	 Top 1-err 33.010  Top 5-err 2.720	 Test Loss 0.951
# Current best accuracy (top-1 and 5 error): 31.22 2.22
# Epoch: [57/300][0/500]	LR: 0.100000	Time 0.174 (0.174)	Loss 0.9778 (0.9778)	Top 1-err 37.0000 (37.0000)
# Epoch: [57/300][100/500]	LR: 0.100000	Time 0.011 (0.011)	Loss 0.9636 (0.8993)	Top 1-err 34.0000 (31.4653)
# Epoch: [57/300][200/500]	LR: 0.100000	Time 0.011 (0.011)	Loss 0.8947 (0.9041)	Top 1-err 30.0000 (31.8259)
# ...
# Epoch: [281/300][100/500]	LR: 0.000000	Time 0.023 (0.012)	Loss 0.7308 (0.7317)	Top 1-err 27.0000 (25.2178)
# Epoch: [281/300][200/500]	LR: 0.000000	Time 0.003 (0.011)	Loss 0.9069 (0.7198)	Top 1-err 28.0000 (24.7313)
# Epoch: [281/300][300/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.5728 (0.7163)	Top 1-err 17.0000 (24.6379)
# Epoch: [281/300][400/500]	LR: 0.000000	Time 0.007 (0.011)	Loss 0.7402 (0.7182)	Top 1-err 19.0000 (24.5112)
# * Epoch: [281/300]	 Top 1-err 24.226  Top 5-err 1.562	 Train Loss 0.713
# Test (on val set): [281/300][0/100]	Time 0.153 (0.153)	Loss 0.6178 (0.6178)	Top 1-err 22.0000 (22.0000)
# * Epoch: [281/300]	 Top 1-err 25.770  Top 5-err 1.750	 Test Loss 0.760
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [282/300][0/500]	LR: 0.000000	Time 0.183 (0.183)	Loss 0.6789 (0.6789)	Top 1-err 23.0000 (23.0000)
# Epoch: [282/300][100/500]	LR: 0.000000	Time 0.007 (0.012)	Loss 0.7184 (0.7359)	Top 1-err 23.0000 (25.1188)
# Epoch: [282/300][200/500]	LR: 0.000000	Time 0.014 (0.011)	Loss 0.6343 (0.7271)	Top 1-err 23.0000 (24.7811)
# Epoch: [282/300][300/500]	LR: 0.000000	Time 0.007 (0.011)	Loss 0.8018 (0.7229)	Top 1-err 26.0000 (24.7542)
# Epoch: [282/300][400/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.6884 (0.7228)	Top 1-err 18.0000 (24.7781)
# * Epoch: [282/300]	 Top 1-err 24.710  Top 5-err 1.582	 Train Loss 0.720
# Test (on val set): [282/300][0/100]	Time 0.160 (0.160)	Loss 0.8168 (0.8168)	Top 1-err 28.0000 (28.0000)
# * Epoch: [282/300]	 Top 1-err 25.680  Top 5-err 1.730	 Test Loss 0.761
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [283/300][0/500]	LR: 0.000000	Time 0.184 (0.184)	Loss 0.7306 (0.7306)	Top 1-err 24.0000 (24.0000)
# Epoch: [283/300][100/500]	LR: 0.000000	Time 0.004 (0.012)	Loss 0.5977 (0.7044)	Top 1-err 18.0000 (24.5248)
# Epoch: [283/300][200/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.8109 (0.7190)	Top 1-err 25.0000 (24.9900)
# Epoch: [283/300][300/500]	LR: 0.000000	Time 0.036 (0.011)	Loss 0.8949 (0.7162)	Top 1-err 29.0000 (24.8837)
# Epoch: [283/300][400/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.6405 (0.7165)	Top 1-err 21.0000 (24.8279)
# * Epoch: [283/300]	 Top 1-err 24.716  Top 5-err 1.512	 Train Loss 0.717
# Test (on val set): [283/300][0/100]	Time 0.158 (0.158)	Loss 0.9696 (0.9696)	Top 1-err 33.0000 (33.0000)
# * Epoch: [283/300]	 Top 1-err 25.880  Top 5-err 1.700	 Test Loss 0.761
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [284/300][0/500]	LR: 0.000000	Time 0.181 (0.181)	Loss 0.8230 (0.8230)	Top 1-err 27.0000 (27.0000)
# Epoch: [284/300][100/500]	LR: 0.000000	Time 0.005 (0.012)	Loss 0.6654 (0.7165)	Top 1-err 23.0000 (24.5149)
# Epoch: [284/300][200/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.7401 (0.7150)	Top 1-err 25.0000 (24.5075)
# Epoch: [284/300][300/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.6469 (0.7148)	Top 1-err 22.0000 (24.5781)
# Epoch: [284/300][400/500]	LR: 0.000000	Time 0.020 (0.011)	Loss 0.7049 (0.7140)	Top 1-err 21.0000 (24.6509)
# * Epoch: [284/300]	 Top 1-err 24.740  Top 5-err 1.564	 Train Loss 0.717
# Test (on val set): [284/300][0/100]	Time 0.151 (0.151)	Loss 0.7780 (0.7780)	Top 1-err 31.0000 (31.0000)
# * Epoch: [284/300]	 Top 1-err 25.780  Top 5-err 1.760	 Test Loss 0.760
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [285/300][0/500]	LR: 0.000000	Time 0.160 (0.160)	Loss 0.6577 (0.6577)	Top 1-err 24.0000 (24.0000)
# Epoch: [285/300][100/500]	LR: 0.000000	Time 0.015 (0.012)	Loss 0.7817 (0.7091)	Top 1-err 32.0000 (25.0792)
# Epoch: [285/300][200/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.7485 (0.7074)	Top 1-err 29.0000 (24.6965)
# Epoch: [285/300][300/500]	LR: 0.000000	Time 0.014 (0.011)	Loss 0.7866 (0.7127)	Top 1-err 22.0000 (24.6478)
# Epoch: [285/300][400/500]	LR: 0.000000	Time 0.014 (0.011)	Loss 0.8491 (0.7170)	Top 1-err 29.0000 (24.8304)
# * Epoch: [285/300]	 Top 1-err 24.620  Top 5-err 1.480	 Train Loss 0.713
# Test (on val set): [285/300][0/100]	Time 0.142 (0.142)	Loss 0.7972 (0.7972)	Top 1-err 24.0000 (24.0000)
# * Epoch: [285/300]	 Top 1-err 25.790  Top 5-err 1.710	 Test Loss 0.763
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [286/300][0/500]	LR: 0.000000	Time 0.162 (0.162)	Loss 0.7419 (0.7419)	Top 1-err 25.0000 (25.0000)
# Epoch: [286/300][100/500]	LR: 0.000000	Time 0.004 (0.012)	Loss 0.5063 (0.7135)	Top 1-err 18.0000 (24.1782)
# Epoch: [286/300][200/500]	LR: 0.000000	Time 0.017 (0.011)	Loss 0.6253 (0.7102)	Top 1-err 22.0000 (24.1294)
# Epoch: [286/300][300/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.7145 (0.7135)	Top 1-err 27.0000 (24.3621)
# Epoch: [286/300][400/500]	LR: 0.000000	Time 0.003 (0.011)	Loss 0.6962 (0.7127)	Top 1-err 23.0000 (24.4214)
# * Epoch: [286/300]	 Top 1-err 24.426  Top 5-err 1.512	 Train Loss 0.713
# Test (on val set): [286/300][0/100]	Time 0.160 (0.160)	Loss 0.6828 (0.6828)	Top 1-err 25.0000 (25.0000)
# * Epoch: [286/300]	 Top 1-err 25.960  Top 5-err 1.720	 Test Loss 0.762
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [287/300][0/500]	LR: 0.000000	Time 0.169 (0.169)	Loss 0.8497 (0.8497)	Top 1-err 29.0000 (29.0000)
# Epoch: [287/300][100/500]	LR: 0.000000	Time 0.008 (0.012)	Loss 0.6980 (0.7119)	Top 1-err 22.0000 (24.6238)
# Epoch: [287/300][200/500]	LR: 0.000000	Time 0.003 (0.011)	Loss 0.6075 (0.7139)	Top 1-err 18.0000 (24.3532)
# Epoch: [287/300][300/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.6617 (0.7134)	Top 1-err 27.0000 (24.4518)
# Epoch: [287/300][400/500]	LR: 0.000000	Time 0.029 (0.011)	Loss 0.8692 (0.7157)	Top 1-err 28.0000 (24.6259)
# * Epoch: [287/300]	 Top 1-err 24.528  Top 5-err 1.560	 Train Loss 0.714
# Test (on val set): [287/300][0/100]	Time 0.172 (0.172)	Loss 0.8070 (0.8070)	Top 1-err 30.0000 (30.0000)
# * Epoch: [287/300]	 Top 1-err 25.820  Top 5-err 1.750	 Test Loss 0.763
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [288/300][0/500]	LR: 0.000000	Time 0.173 (0.173)	Loss 0.8060 (0.8060)	Top 1-err 27.0000 (27.0000)
# Epoch: [288/300][100/500]	LR: 0.000000	Time 0.014 (0.012)	Loss 0.6719 (0.7141)	Top 1-err 27.0000 (24.6535)
# Epoch: [288/300][200/500]	LR: 0.000000	Time 0.006 (0.011)	Loss 0.6243 (0.7077)	Top 1-err 19.0000 (24.2736)
# Epoch: [288/300][300/500]	LR: 0.000000	Time 0.020 (0.011)	Loss 0.7233 (0.7118)	Top 1-err 21.0000 (24.5316)
# Epoch: [288/300][400/500]	LR: 0.000000	Time 0.003 (0.011)	Loss 0.7959 (0.7165)	Top 1-err 32.0000 (24.6259)
# * Epoch: [288/300]	 Top 1-err 24.636  Top 5-err 1.538	 Train Loss 0.717
# Test (on val set): [288/300][0/100]	Time 0.157 (0.157)	Loss 0.7709 (0.7709)	Top 1-err 24.0000 (24.0000)
# * Epoch: [288/300]	 Top 1-err 25.770  Top 5-err 1.740	 Test Loss 0.761
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [289/300][0/500]	LR: 0.000000	Time 0.178 (0.178)	Loss 0.8280 (0.8280)	Top 1-err 27.0000 (27.0000)
# Epoch: [289/300][100/500]	LR: 0.000000	Time 0.013 (0.012)	Loss 0.6633 (0.7146)	Top 1-err 21.0000 (24.2277)
# Epoch: [289/300][200/500]	LR: 0.000000	Time 0.006 (0.011)	Loss 0.5817 (0.7166)	Top 1-err 18.0000 (24.3582)
# Epoch: [289/300][300/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.7572 (0.7218)	Top 1-err 27.0000 (24.6412)
# Epoch: [289/300][400/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.6799 (0.7201)	Top 1-err 25.0000 (24.6459)
# * Epoch: [289/300]	 Top 1-err 24.680  Top 5-err 1.602	 Train Loss 0.719
# Test (on val set): [289/300][0/100]	Time 0.159 (0.159)	Loss 0.6981 (0.6981)	Top 1-err 30.0000 (30.0000)
# * Epoch: [289/300]	 Top 1-err 25.810  Top 5-err 1.680	 Test Loss 0.761
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [290/300][0/500]	LR: 0.000000	Time 0.187 (0.187)	Loss 0.8065 (0.8065)	Top 1-err 28.0000 (28.0000)
# Epoch: [290/300][100/500]	LR: 0.000000	Time 0.014 (0.012)	Loss 0.7720 (0.7001)	Top 1-err 23.0000 (24.4356)
# Epoch: [290/300][200/500]	LR: 0.000000	Time 0.013 (0.011)	Loss 0.7325 (0.7094)	Top 1-err 22.0000 (24.7562)
# Epoch: [290/300][300/500]	LR: 0.000000	Time 0.005 (0.011)	Loss 0.5956 (0.7180)	Top 1-err 19.0000 (24.8206)
# Epoch: [290/300][400/500]	LR: 0.000000	Time 0.003 (0.011)	Loss 0.8035 (0.7157)	Top 1-err 29.0000 (24.6833)
# * Epoch: [290/300]	 Top 1-err 24.558  Top 5-err 1.536	 Train Loss 0.712
# Test (on val set): [290/300][0/100]	Time 0.167 (0.167)	Loss 0.5668 (0.5668)	Top 1-err 21.0000 (21.0000)
# * Epoch: [290/300]	 Top 1-err 25.860  Top 5-err 1.700	 Test Loss 0.761
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [291/300][0/500]	LR: 0.000000	Time 0.163 (0.163)	Loss 0.8904 (0.8904)	Top 1-err 32.0000 (32.0000)
# Epoch: [291/300][100/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.7219 (0.7109)	Top 1-err 24.0000 (24.3762)
# Epoch: [291/300][200/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.7411 (0.7145)	Top 1-err 27.0000 (24.5622)
# Epoch: [291/300][300/500]	LR: 0.000000	Time 0.014 (0.011)	Loss 0.7600 (0.7129)	Top 1-err 21.0000 (24.4452)
# Epoch: [291/300][400/500]	LR: 0.000000	Time 0.022 (0.011)	Loss 0.6906 (0.7125)	Top 1-err 24.0000 (24.4090)
# * Epoch: [291/300]	 Top 1-err 24.442  Top 5-err 1.532	 Train Loss 0.716
# Test (on val set): [291/300][0/100]	Time 0.134 (0.134)	Loss 0.7916 (0.7916)	Top 1-err 30.0000 (30.0000)
# * Epoch: [291/300]	 Top 1-err 25.860  Top 5-err 1.720	 Test Loss 0.762
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [292/300][0/500]	LR: 0.000000	Time 0.174 (0.174)	Loss 0.6650 (0.6650)	Top 1-err 24.0000 (24.0000)
# Epoch: [292/300][100/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.6620 (0.7272)	Top 1-err 20.0000 (25.0990)
# Epoch: [292/300][200/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.7482 (0.7248)	Top 1-err 26.0000 (24.8657)
# Epoch: [292/300][300/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.6539 (0.7234)	Top 1-err 24.0000 (24.7143)
# Epoch: [292/300][400/500]	LR: 0.000000	Time 0.013 (0.011)	Loss 0.7226 (0.7206)	Top 1-err 24.0000 (24.6334)
# * Epoch: [292/300]	 Top 1-err 24.640  Top 5-err 1.522	 Train Loss 0.717
# Test (on val set): [292/300][0/100]	Time 0.170 (0.170)	Loss 0.8600 (0.8600)	Top 1-err 29.0000 (29.0000)
# * Epoch: [292/300]	 Top 1-err 25.770  Top 5-err 1.740	 Test Loss 0.760
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [293/300][0/500]	LR: 0.000000	Time 0.179 (0.179)	Loss 0.6094 (0.6094)	Top 1-err 18.0000 (18.0000)
# Epoch: [293/300][100/500]	LR: 0.000000	Time 0.016 (0.012)	Loss 0.7785 (0.7233)	Top 1-err 30.0000 (25.0990)
# Epoch: [293/300][200/500]	LR: 0.000000	Time 0.006 (0.011)	Loss 0.5960 (0.7203)	Top 1-err 19.0000 (24.9055)
# Epoch: [293/300][300/500]	LR: 0.000000	Time 0.032 (0.011)	Loss 0.6183 (0.7173)	Top 1-err 21.0000 (24.8372)
# Epoch: [293/300][400/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.7843 (0.7165)	Top 1-err 25.0000 (24.8130)
# * Epoch: [293/300]	 Top 1-err 24.750  Top 5-err 1.460	 Train Loss 0.715
# Test (on val set): [293/300][0/100]	Time 0.150 (0.150)	Loss 0.7736 (0.7736)	Top 1-err 21.0000 (21.0000)
# * Epoch: [293/300]	 Top 1-err 25.710  Top 5-err 1.740	 Test Loss 0.760
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [294/300][0/500]	LR: 0.000000	Time 0.184 (0.184)	Loss 0.6108 (0.6108)	Top 1-err 20.0000 (20.0000)
# Epoch: [294/300][100/500]	LR: 0.000000	Time 0.004 (0.012)	Loss 0.6800 (0.7049)	Top 1-err 25.0000 (23.7228)
# Epoch: [294/300][200/500]	LR: 0.000000	Time 0.026 (0.011)	Loss 0.6533 (0.7063)	Top 1-err 22.0000 (23.8756)
# Epoch: [294/300][300/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.6741 (0.7115)	Top 1-err 22.0000 (24.2791)
# Epoch: [294/300][400/500]	LR: 0.000000	Time 0.003 (0.011)	Loss 0.7118 (0.7148)	Top 1-err 19.0000 (24.3466)
# * Epoch: [294/300]	 Top 1-err 24.464  Top 5-err 1.530	 Train Loss 0.715
# Test (on val set): [294/300][0/100]	Time 0.153 (0.153)	Loss 0.7089 (0.7089)	Top 1-err 23.0000 (23.0000)
# * Epoch: [294/300]	 Top 1-err 25.750  Top 5-err 1.730	 Test Loss 0.760
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [295/300][0/500]	LR: 0.000000	Time 0.181 (0.181)	Loss 0.8211 (0.8211)	Top 1-err 32.0000 (32.0000)
# Epoch: [295/300][100/500]	LR: 0.000000	Time 0.004 (0.012)	Loss 0.6393 (0.7214)	Top 1-err 23.0000 (24.5941)
# Epoch: [295/300][200/500]	LR: 0.000000	Time 0.009 (0.011)	Loss 0.8269 (0.7214)	Top 1-err 33.0000 (24.7164)
# Epoch: [295/300][300/500]	LR: 0.000000	Time 0.003 (0.011)	Loss 0.7627 (0.7223)	Top 1-err 33.0000 (24.8904)
# Epoch: [295/300][400/500]	LR: 0.000000	Time 0.018 (0.011)	Loss 0.7062 (0.7183)	Top 1-err 30.0000 (24.7880)
# * Epoch: [295/300]	 Top 1-err 24.708  Top 5-err 1.528	 Train Loss 0.717
# Test (on val set): [295/300][0/100]	Time 0.157 (0.157)	Loss 0.8181 (0.8181)	Top 1-err 32.0000 (32.0000)
# * Epoch: [295/300]	 Top 1-err 25.780  Top 5-err 1.740	 Test Loss 0.761
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [296/300][0/500]	LR: 0.000000	Time 0.193 (0.193)	Loss 0.7931 (0.7931)	Top 1-err 31.0000 (31.0000)
# Epoch: [296/300][100/500]	LR: 0.000000	Time 0.017 (0.012)	Loss 0.6861 (0.7084)	Top 1-err 23.0000 (24.5446)
# Epoch: [296/300][200/500]	LR: 0.000000	Time 0.023 (0.011)	Loss 0.6731 (0.7083)	Top 1-err 28.0000 (24.1940)
# Epoch: [296/300][300/500]	LR: 0.000000	Time 0.032 (0.011)	Loss 0.6505 (0.7096)	Top 1-err 18.0000 (24.3555)
# Epoch: [296/300][400/500]	LR: 0.000000	Time 0.021 (0.011)	Loss 0.6624 (0.7130)	Top 1-err 20.0000 (24.5262)
# * Epoch: [296/300]	 Top 1-err 24.624  Top 5-err 1.544	 Train Loss 0.714
# Test (on val set): [296/300][0/100]	Time 0.153 (0.153)	Loss 0.7676 (0.7676)	Top 1-err 26.0000 (26.0000)
# * Epoch: [296/300]	 Top 1-err 25.800  Top 5-err 1.700	 Test Loss 0.760
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [297/300][0/500]	LR: 0.000000	Time 0.188 (0.188)	Loss 0.8922 (0.8922)	Top 1-err 29.0000 (29.0000)
# Epoch: [297/300][100/500]	LR: 0.000000	Time 0.004 (0.012)	Loss 0.7816 (0.7111)	Top 1-err 26.0000 (24.2772)
# Epoch: [297/300][200/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.6670 (0.7074)	Top 1-err 21.0000 (24.4279)
# Epoch: [297/300][300/500]	LR: 0.000000	Time 0.032 (0.011)	Loss 0.7770 (0.7138)	Top 1-err 25.0000 (24.4319)
# Epoch: [297/300][400/500]	LR: 0.000000	Time 0.007 (0.011)	Loss 0.6476 (0.7134)	Top 1-err 23.0000 (24.4439)
# * Epoch: [297/300]	 Top 1-err 24.390  Top 5-err 1.454	 Train Loss 0.713
# Test (on val set): [297/300][0/100]	Time 0.147 (0.147)	Loss 0.6625 (0.6625)	Top 1-err 25.0000 (25.0000)
# * Epoch: [297/300]	 Top 1-err 25.840  Top 5-err 1.700	 Test Loss 0.760
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [298/300][0/500]	LR: 0.000000	Time 0.170 (0.170)	Loss 0.7667 (0.7667)	Top 1-err 30.0000 (30.0000)
# Epoch: [298/300][100/500]	LR: 0.000000	Time 0.014 (0.012)	Loss 0.8186 (0.7209)	Top 1-err 32.0000 (24.9505)
# Epoch: [298/300][200/500]	LR: 0.000000	Time 0.016 (0.011)	Loss 0.7777 (0.7141)	Top 1-err 25.0000 (24.6567)
# Epoch: [298/300][300/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.8127 (0.7149)	Top 1-err 27.0000 (24.7708)
# Epoch: [298/300][400/500]	LR: 0.000000	Time 0.035 (0.011)	Loss 0.4926 (0.7147)	Top 1-err 17.0000 (24.7880)
# * Epoch: [298/300]	 Top 1-err 24.624  Top 5-err 1.530	 Train Loss 0.715
# Test (on val set): [298/300][0/100]	Time 0.153 (0.153)	Loss 0.7154 (0.7154)	Top 1-err 21.0000 (21.0000)
# * Epoch: [298/300]	 Top 1-err 25.730  Top 5-err 1.730	 Test Loss 0.761
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Epoch: [299/300][0/500]	LR: 0.000000	Time 0.169 (0.169)	Loss 0.7087 (0.7087)	Top 1-err 25.0000 (25.0000)
# Epoch: [299/300][100/500]	LR: 0.000000	Time 0.018 (0.012)	Loss 0.7477 (0.7313)	Top 1-err 25.0000 (25.2574)
# Epoch: [299/300][200/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.9160 (0.7256)	Top 1-err 33.0000 (24.8159)
# Epoch: [299/300][300/500]	LR: 0.000000	Time 0.032 (0.011)	Loss 0.6570 (0.7233)	Top 1-err 24.0000 (24.8472)
# Epoch: [299/300][400/500]	LR: 0.000000	Time 0.004 (0.011)	Loss 0.5880 (0.7176)	Top 1-err 17.0000 (24.6209)
# * Epoch: [299/300]	 Top 1-err 24.578  Top 5-err 1.536	 Train Loss 0.715
# Test (on val set): [299/300][0/100]	Time 0.157 (0.157)	Loss 0.6606 (0.6606)	Top 1-err 21.0000 (21.0000)
# * Epoch: [299/300]	 Top 1-err 25.920  Top 5-err 1.740	 Test Loss 0.762
# Current best accuracy (top-1 and 5 error): 25.64 1.76
# Best accuracy (top-1 and 5 error): 25.64 1.76
